# %%
import json
import re

# %%
s3 = json.load(open("../s3.json"))

# %%
def tabs(n):
    return "  " * n

def filter_operations(shapes):
   return { k:v for k, v in shapes.items() if v["type"] == "operation"}

def input_member_for_operation(operation_id):
   return operation_id + "Request"

# Clean a doc string for OpenAI's OpenAPI format.
# Notably, remove HTML tags, newlines and tabs, and truncate to 200 chars since that's the limit.
# https://platform.openai.com/docs/plugins/getting-started/openapi-definition
def clean_docstring(string): 
   TAGS_REGEX = re.compile('<.*?>') 
   WHITESPACE_REGEX = re.compile('\s+')
   string = re.sub(TAGS_REGEX, '', string)  # Remove HTML tags in documentation like <p>, <a>, etc.
   string = re.sub(WHITESPACE_REGEX, ' ', string)  # Replace all more-than-one spaces with just one space
   return string.replace("\n", "").replace("\t", "")[:200]  # Remove newlines, tabs, and truncate

def convert_member_type(member_type):
  if member_type in ["blob", "timestamp", "enum"]:
    return "string"
  elif member_type == "long":
    return "integer"
  elif member_type == "structure" or member_type == "map":
    return "object"
  elif member_type == "list":
    return "array"
  else:
    return member_type

def write_openapi_header(f):
    f.write("""openapi: 3.0.1
info:
  version: 'v1'
  title: AWS SDK for Natural Language
  description: Use AWS with natural language
servers:
  - url: https://gpt4-plugin-test-mataslauzadis.vercel.app/
""")

def write_paths(f, shapes):
    f.write("paths:\n")

    shapes = filter_operations(shapes)
    # shapes = { k:v for k, v in shapes.items() if k == "com.amazonaws.s3#PutObject" }

    for shape in shapes:
      endpoint = shapes[shape]["input"]["target"]  # i.e com.amazonaws.s3#AbortMultipartUploadRequest
      endpoint = endpoint.replace(".", "#")  # i.e com#amazonaws#s3#AbortMultipartUploadRequest
      endpoint = "/" + "/".join(endpoint.split("#"))  # i.e /com/amazonaws/s3/AbortMultipartUploadRequest

      f.write(tabs(1) + endpoint + ":\n")

      # Write HTTP Method (GET, POST, DELETE, etc.)
      # TODO Manually setting everything to POST
      http_trait = shapes[shape]["traits"].get("smithy.api#http")
      f.write(tabs(2) + "POST:\n")

      # Write Operation ID
      operation_id = endpoint.split("/")[-1]  # i.e AbortMultipartUploadRequest
      f.write(tabs(3) + f"operationId: {operation_id}\n")

      # Write summary
      documentation = shapes[shape]["traits"].get("smithy.api#documentation")
      if documentation is not None:
        # pass
        f.write(tabs(3) + f"summary: {clean_docstring(documentation)}\n")

      # Write input
      input_target = shapes[shape]["input"]["target"]
      f.write(tabs(3) + "requestBody:\n")
      f.write(tabs(4) + "required: true\n")
      f.write(tabs(4) + "content:\n")
      f.write(tabs(5) + "application/json:\n")
      f.write(tabs(6) + "schema:\n")
      f.write(tabs(7) + f"$ref: {input_target}\n")

      # Write responses (only specify HTTP 200 OK response for now)
      f.write(tabs(3) + "responses:\n")
      f.write(tabs(4) + "\"200\":\n")
      f.write(tabs(5) + "description: \"OK\"\n")
      f.write(tabs(5) + "content:\n")
      f.write(tabs(6) + "text:\n")
      f.write(tabs(7) + "\"OK\"\n")

      # Operation done, write newline separator
      f.write("\n")

def write_schemas(f, shapes):
    f.write("components:\n")
    f.write(tabs(1) + "schemas:\n")

    operations = filter_operations(shapes)
    # operations = { k:v for k, v in operations.items() if k == "com.amazonaws.s3#PutObject" }

    for shape in operations:
      input_target = shapes[shape]["input"]["target"]
      write_schema_recursive(f, shapes, input_target, 2)

def write_schema_recursive(f, shapes, shape, num_tabs = 2):
  print(f"Processing {shape}")
  if (shape == "smithy.api#Unit"): return

  f.write(tabs(num_tabs) + shape + ":\n")
  f.write(tabs(num_tabs + 1) + f"type: {convert_member_type(shapes[shape]['type'])}\n")
  f.write(tabs(num_tabs + 1) + "properties:\n")

  for member in shapes[shape]["members"]:
    member_target = shapes[shape]["members"][member]["target"]
    print(f"Processing member {member}")
    if is_member_terminal(shapes[member_target]):
      print(f"Reached terminal member {member}")
      write_terminal_member(f, member_target, shapes, num_tabs + 2)
    else:
      print(f"Recursing on {member}")
      write_schema_recursive(f, shapes, member_target, num_tabs + 2)


TERMINAL_TYPES = ["string", "boolean", "integer", "timestamp", "long", "blob", "enum", "list", "map"]
def is_member_terminal(member):
  return member["type"] in TERMINAL_TYPES


def write_terminal_member(f, member, shapes, num_tabs=4):
  member_type = shapes[member]["type"]
  print(f"Writing terminal member {member} of type {member_type}")

  # Write property name
  f.write(tabs(num_tabs) + member + ":\n")

  # Write property type
  f.write(tabs(num_tabs+1) + f"type: {convert_member_type(member_type)}\n")

  if member_type == "map":
     f.write(tabs(num_tabs + 1) + "additionalProperties:\n")
     # FIXME OpenAPI can only model map types as a string. 
     # add validation to make sure the Smithy model map types are only strings.
     f.write(tabs(num_tabs + 2) + "type: string")

  # Finish writing enum
  if member_type == "enum":
    f.write(tabs(num_tabs+1) + "enum: [")
    enum_shape = shapes[member]
    enum_values = [enum_shape["members"][member]["traits"]["smithy.api#enumValue"] for member in enum_shape["members"]]
    f.write(",".join(enum_values))
    f.write("]\n")

  # Finish writing list
  # if member_type == "list":
    # list_member_target = shapes[member["target"]]["member"]["target"]
    # list_member_type = shapes[list_member_target]
    # f.write(tabs(num_tabs+1) + "items:\n")
    # f.write(tabs(num_tabs+2) + f"type: poopy\n")

  # Write documentation
  if shapes[member].get("traits") is not None and shapes[member].get("traits").get("smithy.api#documentation") is not None:
    f.write(tabs(num_tabs+1) + f"description: {clean_docstring(shapes[member]['traits']['smithy.api#documentation'])}\n")

  # TODO Write "required" property

# def write_member(member, shapes, num_tabs = 4):
#     terminal_types = ["string", "boolean", "integer", "timestamp", "long", "blob", "enum", "list"]
#     member_type = member["type"]
#     if member_type in terminal_types:
#       write_terminal_member(f, member, shapes)
#     else:
#       if member_type == "structure":
#         f.write(tabs(4) + member["target"] + ":\n")
#         f.write(tabs(5) + f"type: {convert_member_type(member_type)}\n")
#         f.write(tabs(5) + "properties:\n")
#         for submember_name in shapes[member["target"]]["members"]:
#           submember = shapes[shapes[member["target"]]["members"][submember_name]["target"]]
#           print(submember)
#           if submember["type"] in terminal_types:
#              write_terminal_member(f, submember, shapes, 6)
#           else: raise Exception(member_type + "sub member is not terminal.")

with open("../openapi.yaml", "w") as f:
    write_openapi_header(f)
    write_paths(f, s3["shapes"])
    write_schemas(f, s3["shapes"])
# Out:
# Processing com.amazonaws.s3#AbortMultipartUploadRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member UploadId
# Reached terminal member UploadId
# Writing terminal member com.amazonaws.s3#MultipartUploadId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#CompleteMultipartUploadRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member MultipartUpload
# Recursing on MultipartUpload
# Processing com.amazonaws.s3#CompletedMultipartUpload
# Processing member Parts
# Reached terminal member Parts
# Writing terminal member com.amazonaws.s3#CompletedPartList of type list
# Processing member UploadId
# Reached terminal member UploadId
# Writing terminal member com.amazonaws.s3#MultipartUploadId of type string
# Processing member ChecksumCRC32
# Reached terminal member ChecksumCRC32
# Writing terminal member com.amazonaws.s3#ChecksumCRC32 of type string
# Processing member ChecksumCRC32C
# Reached terminal member ChecksumCRC32C
# Writing terminal member com.amazonaws.s3#ChecksumCRC32C of type string
# Processing member ChecksumSHA1
# Reached terminal member ChecksumSHA1
# Writing terminal member com.amazonaws.s3#ChecksumSHA1 of type string
# Processing member ChecksumSHA256
# Reached terminal member ChecksumSHA256
# Writing terminal member com.amazonaws.s3#ChecksumSHA256 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing com.amazonaws.s3#CopyObjectRequest
# Processing member ACL
# Reached terminal member ACL
# Writing terminal member com.amazonaws.s3#ObjectCannedACL of type enum
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member CacheControl
# Reached terminal member CacheControl
# Writing terminal member com.amazonaws.s3#CacheControl of type string
# Processing member ChecksumAlgorithm
# Reached terminal member ChecksumAlgorithm
# Writing terminal member com.amazonaws.s3#ChecksumAlgorithm of type enum
# Processing member ContentDisposition
# Reached terminal member ContentDisposition
# Writing terminal member com.amazonaws.s3#ContentDisposition of type string
# Processing member ContentEncoding
# Reached terminal member ContentEncoding
# Writing terminal member com.amazonaws.s3#ContentEncoding of type string
# Processing member ContentLanguage
# Reached terminal member ContentLanguage
# Writing terminal member com.amazonaws.s3#ContentLanguage of type string
# Processing member ContentType
# Reached terminal member ContentType
# Writing terminal member com.amazonaws.s3#ContentType of type string
# Processing member CopySource
# Reached terminal member CopySource
# Writing terminal member com.amazonaws.s3#CopySource of type string
# Processing member CopySourceIfMatch
# Reached terminal member CopySourceIfMatch
# Writing terminal member com.amazonaws.s3#CopySourceIfMatch of type string
# Processing member CopySourceIfModifiedSince
# Reached terminal member CopySourceIfModifiedSince
# Writing terminal member com.amazonaws.s3#CopySourceIfModifiedSince of type timestamp
# Processing member CopySourceIfNoneMatch
# Reached terminal member CopySourceIfNoneMatch
# Writing terminal member com.amazonaws.s3#CopySourceIfNoneMatch of type string
# Processing member CopySourceIfUnmodifiedSince
# Reached terminal member CopySourceIfUnmodifiedSince
# Writing terminal member com.amazonaws.s3#CopySourceIfUnmodifiedSince of type timestamp
# Processing member Expires
# Reached terminal member Expires
# Writing terminal member com.amazonaws.s3#Expires of type timestamp
# Processing member GrantFullControl
# Reached terminal member GrantFullControl
# Writing terminal member com.amazonaws.s3#GrantFullControl of type string
# Processing member GrantRead
# Reached terminal member GrantRead
# Writing terminal member com.amazonaws.s3#GrantRead of type string
# Processing member GrantReadACP
# Reached terminal member GrantReadACP
# Writing terminal member com.amazonaws.s3#GrantReadACP of type string
# Processing member GrantWriteACP
# Reached terminal member GrantWriteACP
# Writing terminal member com.amazonaws.s3#GrantWriteACP of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member Metadata
# Reached terminal member Metadata
# Writing terminal member com.amazonaws.s3#Metadata of type map
# Processing member MetadataDirective
# Reached terminal member MetadataDirective
# Writing terminal member com.amazonaws.s3#MetadataDirective of type enum
# Processing member TaggingDirective
# Reached terminal member TaggingDirective
# Writing terminal member com.amazonaws.s3#TaggingDirective of type enum
# Processing member ServerSideEncryption
# Reached terminal member ServerSideEncryption
# Writing terminal member com.amazonaws.s3#ServerSideEncryption of type enum
# Processing member StorageClass
# Reached terminal member StorageClass
# Writing terminal member com.amazonaws.s3#StorageClass of type enum
# Processing member WebsiteRedirectLocation
# Reached terminal member WebsiteRedirectLocation
# Writing terminal member com.amazonaws.s3#WebsiteRedirectLocation of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member SSEKMSKeyId
# Reached terminal member SSEKMSKeyId
# Writing terminal member com.amazonaws.s3#SSEKMSKeyId of type string
# Processing member SSEKMSEncryptionContext
# Reached terminal member SSEKMSEncryptionContext
# Writing terminal member com.amazonaws.s3#SSEKMSEncryptionContext of type string
# Processing member BucketKeyEnabled
# Reached terminal member BucketKeyEnabled
# Writing terminal member com.amazonaws.s3#BucketKeyEnabled of type boolean
# Processing member CopySourceSSECustomerAlgorithm
# Reached terminal member CopySourceSSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerAlgorithm of type string
# Processing member CopySourceSSECustomerKey
# Reached terminal member CopySourceSSECustomerKey
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerKey of type string
# Processing member CopySourceSSECustomerKeyMD5
# Reached terminal member CopySourceSSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member Tagging
# Reached terminal member Tagging
# Writing terminal member com.amazonaws.s3#TaggingHeader of type string
# Processing member ObjectLockMode
# Reached terminal member ObjectLockMode
# Writing terminal member com.amazonaws.s3#ObjectLockMode of type enum
# Processing member ObjectLockRetainUntilDate
# Reached terminal member ObjectLockRetainUntilDate
# Writing terminal member com.amazonaws.s3#ObjectLockRetainUntilDate of type timestamp
# Processing member ObjectLockLegalHoldStatus
# Reached terminal member ObjectLockLegalHoldStatus
# Writing terminal member com.amazonaws.s3#ObjectLockLegalHoldStatus of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ExpectedSourceBucketOwner
# Reached terminal member ExpectedSourceBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#CreateBucketRequest
# Processing member ACL
# Reached terminal member ACL
# Writing terminal member com.amazonaws.s3#BucketCannedACL of type enum
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member CreateBucketConfiguration
# Recursing on CreateBucketConfiguration
# Processing com.amazonaws.s3#CreateBucketConfiguration
# Processing member LocationConstraint
# Reached terminal member LocationConstraint
# Writing terminal member com.amazonaws.s3#BucketLocationConstraint of type enum
# Processing member GrantFullControl
# Reached terminal member GrantFullControl
# Writing terminal member com.amazonaws.s3#GrantFullControl of type string
# Processing member GrantRead
# Reached terminal member GrantRead
# Writing terminal member com.amazonaws.s3#GrantRead of type string
# Processing member GrantReadACP
# Reached terminal member GrantReadACP
# Writing terminal member com.amazonaws.s3#GrantReadACP of type string
# Processing member GrantWrite
# Reached terminal member GrantWrite
# Writing terminal member com.amazonaws.s3#GrantWrite of type string
# Processing member GrantWriteACP
# Reached terminal member GrantWriteACP
# Writing terminal member com.amazonaws.s3#GrantWriteACP of type string
# Processing member ObjectLockEnabledForBucket
# Reached terminal member ObjectLockEnabledForBucket
# Writing terminal member com.amazonaws.s3#ObjectLockEnabledForBucket of type boolean
# Processing member ObjectOwnership
# Reached terminal member ObjectOwnership
# Writing terminal member com.amazonaws.s3#ObjectOwnership of type enum
# Processing com.amazonaws.s3#CreateMultipartUploadRequest
# Processing member ACL
# Reached terminal member ACL
# Writing terminal member com.amazonaws.s3#ObjectCannedACL of type enum
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member CacheControl
# Reached terminal member CacheControl
# Writing terminal member com.amazonaws.s3#CacheControl of type string
# Processing member ContentDisposition
# Reached terminal member ContentDisposition
# Writing terminal member com.amazonaws.s3#ContentDisposition of type string
# Processing member ContentEncoding
# Reached terminal member ContentEncoding
# Writing terminal member com.amazonaws.s3#ContentEncoding of type string
# Processing member ContentLanguage
# Reached terminal member ContentLanguage
# Writing terminal member com.amazonaws.s3#ContentLanguage of type string
# Processing member ContentType
# Reached terminal member ContentType
# Writing terminal member com.amazonaws.s3#ContentType of type string
# Processing member Expires
# Reached terminal member Expires
# Writing terminal member com.amazonaws.s3#Expires of type timestamp
# Processing member GrantFullControl
# Reached terminal member GrantFullControl
# Writing terminal member com.amazonaws.s3#GrantFullControl of type string
# Processing member GrantRead
# Reached terminal member GrantRead
# Writing terminal member com.amazonaws.s3#GrantRead of type string
# Processing member GrantReadACP
# Reached terminal member GrantReadACP
# Writing terminal member com.amazonaws.s3#GrantReadACP of type string
# Processing member GrantWriteACP
# Reached terminal member GrantWriteACP
# Writing terminal member com.amazonaws.s3#GrantWriteACP of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member Metadata
# Reached terminal member Metadata
# Writing terminal member com.amazonaws.s3#Metadata of type map
# Processing member ServerSideEncryption
# Reached terminal member ServerSideEncryption
# Writing terminal member com.amazonaws.s3#ServerSideEncryption of type enum
# Processing member StorageClass
# Reached terminal member StorageClass
# Writing terminal member com.amazonaws.s3#StorageClass of type enum
# Processing member WebsiteRedirectLocation
# Reached terminal member WebsiteRedirectLocation
# Writing terminal member com.amazonaws.s3#WebsiteRedirectLocation of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member SSEKMSKeyId
# Reached terminal member SSEKMSKeyId
# Writing terminal member com.amazonaws.s3#SSEKMSKeyId of type string
# Processing member SSEKMSEncryptionContext
# Reached terminal member SSEKMSEncryptionContext
# Writing terminal member com.amazonaws.s3#SSEKMSEncryptionContext of type string
# Processing member BucketKeyEnabled
# Reached terminal member BucketKeyEnabled
# Writing terminal member com.amazonaws.s3#BucketKeyEnabled of type boolean
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member Tagging
# Reached terminal member Tagging
# Writing terminal member com.amazonaws.s3#TaggingHeader of type string
# Processing member ObjectLockMode
# Reached terminal member ObjectLockMode
# Writing terminal member com.amazonaws.s3#ObjectLockMode of type enum
# Processing member ObjectLockRetainUntilDate
# Reached terminal member ObjectLockRetainUntilDate
# Writing terminal member com.amazonaws.s3#ObjectLockRetainUntilDate of type timestamp
# Processing member ObjectLockLegalHoldStatus
# Reached terminal member ObjectLockLegalHoldStatus
# Writing terminal member com.amazonaws.s3#ObjectLockLegalHoldStatus of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ChecksumAlgorithm
# Reached terminal member ChecksumAlgorithm
# Writing terminal member com.amazonaws.s3#ChecksumAlgorithm of type enum
# Processing com.amazonaws.s3#DeleteBucketRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketAnalyticsConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#AnalyticsId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketCorsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketEncryptionRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketIntelligentTieringConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#IntelligentTieringId of type string
# Processing com.amazonaws.s3#DeleteBucketInventoryConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#InventoryId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketLifecycleRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketMetricsConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#MetricsId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketOwnershipControlsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketPolicyRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketReplicationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketTaggingRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteBucketWebsiteRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteObjectRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member MFA
# Reached terminal member MFA
# Writing terminal member com.amazonaws.s3#MFA of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member BypassGovernanceRetention
# Reached terminal member BypassGovernanceRetention
# Writing terminal member com.amazonaws.s3#BypassGovernanceRetention of type boolean
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteObjectTaggingRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#DeleteObjectsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Delete
# Recursing on Delete
# Processing com.amazonaws.s3#Delete
# Processing member Objects
# Reached terminal member Objects
# Writing terminal member com.amazonaws.s3#ObjectIdentifierList of type list
# Processing member Quiet
# Reached terminal member Quiet
# Writing terminal member com.amazonaws.s3#Quiet of type boolean
# Processing member MFA
# Reached terminal member MFA
# Writing terminal member com.amazonaws.s3#MFA of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member BypassGovernanceRetention
# Reached terminal member BypassGovernanceRetention
# Writing terminal member com.amazonaws.s3#BypassGovernanceRetention of type boolean
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ChecksumAlgorithm
# Reached terminal member ChecksumAlgorithm
# Writing terminal member com.amazonaws.s3#ChecksumAlgorithm of type enum
# Processing com.amazonaws.s3#DeletePublicAccessBlockRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketAccelerateConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketAclRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketAnalyticsConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#AnalyticsId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketCorsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketEncryptionRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketIntelligentTieringConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#IntelligentTieringId of type string
# Processing com.amazonaws.s3#GetBucketInventoryConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#InventoryId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketLifecycleConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketLocationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketLoggingRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketMetricsConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Id
# Reached terminal member Id
# Writing terminal member com.amazonaws.s3#MetricsId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketNotificationConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketOwnershipControlsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketPolicyRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketPolicyStatusRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketReplicationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketRequestPaymentRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketTaggingRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketVersioningRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetBucketWebsiteRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetObjectRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member IfMatch
# Reached terminal member IfMatch
# Writing terminal member com.amazonaws.s3#IfMatch of type string
# Processing member IfModifiedSince
# Reached terminal member IfModifiedSince
# Writing terminal member com.amazonaws.s3#IfModifiedSince of type timestamp
# Processing member IfNoneMatch
# Reached terminal member IfNoneMatch
# Writing terminal member com.amazonaws.s3#IfNoneMatch of type string
# Processing member IfUnmodifiedSince
# Reached terminal member IfUnmodifiedSince
# Writing terminal member com.amazonaws.s3#IfUnmodifiedSince of type timestamp
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member Range
# Reached terminal member Range
# Writing terminal member com.amazonaws.s3#Range of type string
# Processing member ResponseCacheControl
# Reached terminal member ResponseCacheControl
# Writing terminal member com.amazonaws.s3#ResponseCacheControl of type string
# Processing member ResponseContentDisposition
# Reached terminal member ResponseContentDisposition
# Writing terminal member com.amazonaws.s3#ResponseContentDisposition of type string
# Processing member ResponseContentEncoding
# Reached terminal member ResponseContentEncoding
# Writing terminal member com.amazonaws.s3#ResponseContentEncoding of type string
# Processing member ResponseContentLanguage
# Reached terminal member ResponseContentLanguage
# Writing terminal member com.amazonaws.s3#ResponseContentLanguage of type string
# Processing member ResponseContentType
# Reached terminal member ResponseContentType
# Writing terminal member com.amazonaws.s3#ResponseContentType of type string
# Processing member ResponseExpires
# Reached terminal member ResponseExpires
# Writing terminal member com.amazonaws.s3#ResponseExpires of type timestamp
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member PartNumber
# Reached terminal member PartNumber
# Writing terminal member com.amazonaws.s3#PartNumber of type integer
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ChecksumMode
# Reached terminal member ChecksumMode
# Writing terminal member com.amazonaws.s3#ChecksumMode of type enum
# Processing com.amazonaws.s3#GetObjectAclRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetObjectAttributesRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member MaxParts
# Reached terminal member MaxParts
# Writing terminal member com.amazonaws.s3#MaxParts of type integer
# Processing member PartNumberMarker
# Reached terminal member PartNumberMarker
# Writing terminal member com.amazonaws.s3#PartNumberMarker of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ObjectAttributes
# Reached terminal member ObjectAttributes
# Writing terminal member com.amazonaws.s3#ObjectAttributesList of type list
# Processing com.amazonaws.s3#GetObjectLegalHoldRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetObjectLockConfigurationRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetObjectRetentionRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetObjectTaggingRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing com.amazonaws.s3#GetObjectTorrentRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#GetPublicAccessBlockRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#HeadBucketRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#HeadObjectRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member IfMatch
# Reached terminal member IfMatch
# Writing terminal member com.amazonaws.s3#IfMatch of type string
# Processing member IfModifiedSince
# Reached terminal member IfModifiedSince
# Writing terminal member com.amazonaws.s3#IfModifiedSince of type timestamp
# Processing member IfNoneMatch
# Reached terminal member IfNoneMatch
# Writing terminal member com.amazonaws.s3#IfNoneMatch of type string
# Processing member IfUnmodifiedSince
# Reached terminal member IfUnmodifiedSince
# Writing terminal member com.amazonaws.s3#IfUnmodifiedSince of type timestamp
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member Range
# Reached terminal member Range
# Writing terminal member com.amazonaws.s3#Range of type string
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member PartNumber
# Reached terminal member PartNumber
# Writing terminal member com.amazonaws.s3#PartNumber of type integer
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ChecksumMode
# Reached terminal member ChecksumMode
# Writing terminal member com.amazonaws.s3#ChecksumMode of type enum
# Processing com.amazonaws.s3#ListBucketAnalyticsConfigurationsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ContinuationToken
# Reached terminal member ContinuationToken
# Writing terminal member com.amazonaws.s3#Token of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListBucketIntelligentTieringConfigurationsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ContinuationToken
# Reached terminal member ContinuationToken
# Writing terminal member com.amazonaws.s3#Token of type string
# Processing com.amazonaws.s3#ListBucketInventoryConfigurationsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ContinuationToken
# Reached terminal member ContinuationToken
# Writing terminal member com.amazonaws.s3#Token of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListBucketMetricsConfigurationsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ContinuationToken
# Reached terminal member ContinuationToken
# Writing terminal member com.amazonaws.s3#Token of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing smithy.api#Unit
# Processing com.amazonaws.s3#ListMultipartUploadsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Delimiter
# Reached terminal member Delimiter
# Writing terminal member com.amazonaws.s3#Delimiter of type string
# Processing member EncodingType
# Reached terminal member EncodingType
# Writing terminal member com.amazonaws.s3#EncodingType of type enum
# Processing member KeyMarker
# Reached terminal member KeyMarker
# Writing terminal member com.amazonaws.s3#KeyMarker of type string
# Processing member MaxUploads
# Reached terminal member MaxUploads
# Writing terminal member com.amazonaws.s3#MaxUploads of type integer
# Processing member Prefix
# Reached terminal member Prefix
# Writing terminal member com.amazonaws.s3#Prefix of type string
# Processing member UploadIdMarker
# Reached terminal member UploadIdMarker
# Writing terminal member com.amazonaws.s3#UploadIdMarker of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListObjectVersionsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Delimiter
# Reached terminal member Delimiter
# Writing terminal member com.amazonaws.s3#Delimiter of type string
# Processing member EncodingType
# Reached terminal member EncodingType
# Writing terminal member com.amazonaws.s3#EncodingType of type enum
# Processing member KeyMarker
# Reached terminal member KeyMarker
# Writing terminal member com.amazonaws.s3#KeyMarker of type string
# Processing member MaxKeys
# Reached terminal member MaxKeys
# Writing terminal member com.amazonaws.s3#MaxKeys of type integer
# Processing member Prefix
# Reached terminal member Prefix
# Writing terminal member com.amazonaws.s3#Prefix of type string
# Processing member VersionIdMarker
# Reached terminal member VersionIdMarker
# Writing terminal member com.amazonaws.s3#VersionIdMarker of type string
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListObjectsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Delimiter
# Reached terminal member Delimiter
# Writing terminal member com.amazonaws.s3#Delimiter of type string
# Processing member EncodingType
# Reached terminal member EncodingType
# Writing terminal member com.amazonaws.s3#EncodingType of type enum
# Processing member Marker
# Reached terminal member Marker
# Writing terminal member com.amazonaws.s3#Marker of type string
# Processing member MaxKeys
# Reached terminal member MaxKeys
# Writing terminal member com.amazonaws.s3#MaxKeys of type integer
# Processing member Prefix
# Reached terminal member Prefix
# Writing terminal member com.amazonaws.s3#Prefix of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListObjectsV2Request
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Delimiter
# Reached terminal member Delimiter
# Writing terminal member com.amazonaws.s3#Delimiter of type string
# Processing member EncodingType
# Reached terminal member EncodingType
# Writing terminal member com.amazonaws.s3#EncodingType of type enum
# Processing member MaxKeys
# Reached terminal member MaxKeys
# Writing terminal member com.amazonaws.s3#MaxKeys of type integer
# Processing member Prefix
# Reached terminal member Prefix
# Writing terminal member com.amazonaws.s3#Prefix of type string
# Processing member ContinuationToken
# Reached terminal member ContinuationToken
# Writing terminal member com.amazonaws.s3#Token of type string
# Processing member FetchOwner
# Reached terminal member FetchOwner
# Writing terminal member com.amazonaws.s3#FetchOwner of type boolean
# Processing member StartAfter
# Reached terminal member StartAfter
# Writing terminal member com.amazonaws.s3#StartAfter of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#ListPartsRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member MaxParts
# Reached terminal member MaxParts
# Writing terminal member com.amazonaws.s3#MaxParts of type integer
# Processing member PartNumberMarker
# Reached terminal member PartNumberMarker
# Writing terminal member com.amazonaws.s3#PartNumberMarker of type string
# Processing member UploadId
# Reached terminal member UploadId
# Writing terminal member com.amazonaws.s3#MultipartUploadId of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# ...
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ChecksumAlgorithm
# Reached terminal member ChecksumAlgorithm
# Writing terminal member com.amazonaws.s3#ChecksumAlgorithm of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#SelectObjectContentRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member Expression
# Reached terminal member Expression
# Writing terminal member com.amazonaws.s3#Expression of type string
# Processing member ExpressionType
# Reached terminal member ExpressionType
# Writing terminal member com.amazonaws.s3#ExpressionType of type enum
# Processing member RequestProgress
# Recursing on RequestProgress
# Processing com.amazonaws.s3#RequestProgress
# Processing member Enabled
# Reached terminal member Enabled
# Writing terminal member com.amazonaws.s3#EnableRequestProgress of type boolean
# Processing member InputSerialization
# Recursing on InputSerialization
# Processing com.amazonaws.s3#InputSerialization
# Processing member CSV
# Recursing on CSV
# Processing com.amazonaws.s3#CSVInput
# Processing member FileHeaderInfo
# Reached terminal member FileHeaderInfo
# Writing terminal member com.amazonaws.s3#FileHeaderInfo of type enum
# Processing member Comments
# Reached terminal member Comments
# Writing terminal member com.amazonaws.s3#Comments of type string
# Processing member QuoteEscapeCharacter
# Reached terminal member QuoteEscapeCharacter
# Writing terminal member com.amazonaws.s3#QuoteEscapeCharacter of type string
# Processing member RecordDelimiter
# Reached terminal member RecordDelimiter
# Writing terminal member com.amazonaws.s3#RecordDelimiter of type string
# Processing member FieldDelimiter
# Reached terminal member FieldDelimiter
# Writing terminal member com.amazonaws.s3#FieldDelimiter of type string
# Processing member QuoteCharacter
# Reached terminal member QuoteCharacter
# Writing terminal member com.amazonaws.s3#QuoteCharacter of type string
# Processing member AllowQuotedRecordDelimiter
# Reached terminal member AllowQuotedRecordDelimiter
# Writing terminal member com.amazonaws.s3#AllowQuotedRecordDelimiter of type boolean
# Processing member CompressionType
# Reached terminal member CompressionType
# Writing terminal member com.amazonaws.s3#CompressionType of type enum
# Processing member JSON
# Recursing on JSON
# Processing com.amazonaws.s3#JSONInput
# Processing member Type
# Reached terminal member Type
# Writing terminal member com.amazonaws.s3#JSONType of type enum
# Processing member Parquet
# Recursing on Parquet
# Processing com.amazonaws.s3#ParquetInput
# Processing member OutputSerialization
# Recursing on OutputSerialization
# Processing com.amazonaws.s3#OutputSerialization
# Processing member CSV
# Recursing on CSV
# Processing com.amazonaws.s3#CSVOutput
# Processing member QuoteFields
# Reached terminal member QuoteFields
# Writing terminal member com.amazonaws.s3#QuoteFields of type enum
# Processing member QuoteEscapeCharacter
# Reached terminal member QuoteEscapeCharacter
# Writing terminal member com.amazonaws.s3#QuoteEscapeCharacter of type string
# Processing member RecordDelimiter
# Reached terminal member RecordDelimiter
# Writing terminal member com.amazonaws.s3#RecordDelimiter of type string
# Processing member FieldDelimiter
# Reached terminal member FieldDelimiter
# Writing terminal member com.amazonaws.s3#FieldDelimiter of type string
# Processing member QuoteCharacter
# Reached terminal member QuoteCharacter
# Writing terminal member com.amazonaws.s3#QuoteCharacter of type string
# Processing member JSON
# Recursing on JSON
# Processing com.amazonaws.s3#JSONOutput
# Processing member RecordDelimiter
# Reached terminal member RecordDelimiter
# Writing terminal member com.amazonaws.s3#RecordDelimiter of type string
# Processing member ScanRange
# Recursing on ScanRange
# Processing com.amazonaws.s3#ScanRange
# Processing member Start
# Reached terminal member Start
# Writing terminal member com.amazonaws.s3#Start of type long
# Processing member End
# Reached terminal member End
# Writing terminal member com.amazonaws.s3#End of type long
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#UploadPartRequest
# Processing member Body
# Reached terminal member Body
# Writing terminal member com.amazonaws.s3#StreamingBlob of type blob
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member ContentLength
# Reached terminal member ContentLength
# Writing terminal member com.amazonaws.s3#ContentLength of type long
# Processing member ContentMD5
# Reached terminal member ContentMD5
# Writing terminal member com.amazonaws.s3#ContentMD5 of type string
# Processing member ChecksumAlgorithm
# Reached terminal member ChecksumAlgorithm
# Writing terminal member com.amazonaws.s3#ChecksumAlgorithm of type enum
# Processing member ChecksumCRC32
# Reached terminal member ChecksumCRC32
# Writing terminal member com.amazonaws.s3#ChecksumCRC32 of type string
# Processing member ChecksumCRC32C
# Reached terminal member ChecksumCRC32C
# Writing terminal member com.amazonaws.s3#ChecksumCRC32C of type string
# Processing member ChecksumSHA1
# Reached terminal member ChecksumSHA1
# Writing terminal member com.amazonaws.s3#ChecksumSHA1 of type string
# Processing member ChecksumSHA256
# Reached terminal member ChecksumSHA256
# Writing terminal member com.amazonaws.s3#ChecksumSHA256 of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member PartNumber
# Reached terminal member PartNumber
# Writing terminal member com.amazonaws.s3#PartNumber of type integer
# Processing member UploadId
# Reached terminal member UploadId
# Writing terminal member com.amazonaws.s3#MultipartUploadId of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#UploadPartCopyRequest
# Processing member Bucket
# Reached terminal member Bucket
# Writing terminal member com.amazonaws.s3#BucketName of type string
# Processing member CopySource
# Reached terminal member CopySource
# Writing terminal member com.amazonaws.s3#CopySource of type string
# Processing member CopySourceIfMatch
# Reached terminal member CopySourceIfMatch
# Writing terminal member com.amazonaws.s3#CopySourceIfMatch of type string
# Processing member CopySourceIfModifiedSince
# Reached terminal member CopySourceIfModifiedSince
# Writing terminal member com.amazonaws.s3#CopySourceIfModifiedSince of type timestamp
# Processing member CopySourceIfNoneMatch
# Reached terminal member CopySourceIfNoneMatch
# Writing terminal member com.amazonaws.s3#CopySourceIfNoneMatch of type string
# Processing member CopySourceIfUnmodifiedSince
# Reached terminal member CopySourceIfUnmodifiedSince
# Writing terminal member com.amazonaws.s3#CopySourceIfUnmodifiedSince of type timestamp
# Processing member CopySourceRange
# Reached terminal member CopySourceRange
# Writing terminal member com.amazonaws.s3#CopySourceRange of type string
# Processing member Key
# Reached terminal member Key
# Writing terminal member com.amazonaws.s3#ObjectKey of type string
# Processing member PartNumber
# Reached terminal member PartNumber
# Writing terminal member com.amazonaws.s3#PartNumber of type integer
# Processing member UploadId
# Reached terminal member UploadId
# Writing terminal member com.amazonaws.s3#MultipartUploadId of type string
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSECustomerKey
# Reached terminal member SSECustomerKey
# Writing terminal member com.amazonaws.s3#SSECustomerKey of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member CopySourceSSECustomerAlgorithm
# Reached terminal member CopySourceSSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerAlgorithm of type string
# Processing member CopySourceSSECustomerKey
# Reached terminal member CopySourceSSECustomerKey
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerKey of type string
# Processing member CopySourceSSECustomerKeyMD5
# Reached terminal member CopySourceSSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#CopySourceSSECustomerKeyMD5 of type string
# Processing member RequestPayer
# Reached terminal member RequestPayer
# Writing terminal member com.amazonaws.s3#RequestPayer of type enum
# Processing member ExpectedBucketOwner
# Reached terminal member ExpectedBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing member ExpectedSourceBucketOwner
# Reached terminal member ExpectedSourceBucketOwner
# Writing terminal member com.amazonaws.s3#AccountId of type string
# Processing com.amazonaws.s3#WriteGetObjectResponseRequest
# Processing member RequestRoute
# Reached terminal member RequestRoute
# Writing terminal member com.amazonaws.s3#RequestRoute of type string
# Processing member RequestToken
# Reached terminal member RequestToken
# Writing terminal member com.amazonaws.s3#RequestToken of type string
# Processing member Body
# Reached terminal member Body
# Writing terminal member com.amazonaws.s3#StreamingBlob of type blob
# Processing member StatusCode
# Reached terminal member StatusCode
# Writing terminal member com.amazonaws.s3#GetObjectResponseStatusCode of type integer
# Processing member ErrorCode
# Reached terminal member ErrorCode
# Writing terminal member com.amazonaws.s3#ErrorCode of type string
# Processing member ErrorMessage
# Reached terminal member ErrorMessage
# Writing terminal member com.amazonaws.s3#ErrorMessage of type string
# Processing member AcceptRanges
# Reached terminal member AcceptRanges
# Writing terminal member com.amazonaws.s3#AcceptRanges of type string
# Processing member CacheControl
# Reached terminal member CacheControl
# Writing terminal member com.amazonaws.s3#CacheControl of type string
# Processing member ContentDisposition
# Reached terminal member ContentDisposition
# Writing terminal member com.amazonaws.s3#ContentDisposition of type string
# Processing member ContentEncoding
# Reached terminal member ContentEncoding
# Writing terminal member com.amazonaws.s3#ContentEncoding of type string
# Processing member ContentLanguage
# Reached terminal member ContentLanguage
# Writing terminal member com.amazonaws.s3#ContentLanguage of type string
# Processing member ContentLength
# Reached terminal member ContentLength
# Writing terminal member com.amazonaws.s3#ContentLength of type long
# Processing member ContentRange
# Reached terminal member ContentRange
# Writing terminal member com.amazonaws.s3#ContentRange of type string
# Processing member ContentType
# Reached terminal member ContentType
# Writing terminal member com.amazonaws.s3#ContentType of type string
# Processing member ChecksumCRC32
# Reached terminal member ChecksumCRC32
# Writing terminal member com.amazonaws.s3#ChecksumCRC32 of type string
# Processing member ChecksumCRC32C
# Reached terminal member ChecksumCRC32C
# Writing terminal member com.amazonaws.s3#ChecksumCRC32C of type string
# Processing member ChecksumSHA1
# Reached terminal member ChecksumSHA1
# Writing terminal member com.amazonaws.s3#ChecksumSHA1 of type string
# Processing member ChecksumSHA256
# Reached terminal member ChecksumSHA256
# Writing terminal member com.amazonaws.s3#ChecksumSHA256 of type string
# Processing member DeleteMarker
# Reached terminal member DeleteMarker
# Writing terminal member com.amazonaws.s3#DeleteMarker of type boolean
# Processing member ETag
# Reached terminal member ETag
# Writing terminal member com.amazonaws.s3#ETag of type string
# Processing member Expires
# Reached terminal member Expires
# Writing terminal member com.amazonaws.s3#Expires of type timestamp
# Processing member Expiration
# Reached terminal member Expiration
# Writing terminal member com.amazonaws.s3#Expiration of type string
# Processing member LastModified
# Reached terminal member LastModified
# Writing terminal member com.amazonaws.s3#LastModified of type timestamp
# Processing member MissingMeta
# Reached terminal member MissingMeta
# Writing terminal member com.amazonaws.s3#MissingMeta of type integer
# Processing member Metadata
# Reached terminal member Metadata
# Writing terminal member com.amazonaws.s3#Metadata of type map
# Processing member ObjectLockMode
# Reached terminal member ObjectLockMode
# Writing terminal member com.amazonaws.s3#ObjectLockMode of type enum
# Processing member ObjectLockLegalHoldStatus
# Reached terminal member ObjectLockLegalHoldStatus
# Writing terminal member com.amazonaws.s3#ObjectLockLegalHoldStatus of type enum
# Processing member ObjectLockRetainUntilDate
# Reached terminal member ObjectLockRetainUntilDate
# Writing terminal member com.amazonaws.s3#ObjectLockRetainUntilDate of type timestamp
# Processing member PartsCount
# Reached terminal member PartsCount
# Writing terminal member com.amazonaws.s3#PartsCount of type integer
# Processing member ReplicationStatus
# Reached terminal member ReplicationStatus
# Writing terminal member com.amazonaws.s3#ReplicationStatus of type enum
# Processing member RequestCharged
# Reached terminal member RequestCharged
# Writing terminal member com.amazonaws.s3#RequestCharged of type enum
# Processing member Restore
# Reached terminal member Restore
# Writing terminal member com.amazonaws.s3#Restore of type string
# Processing member ServerSideEncryption
# Reached terminal member ServerSideEncryption
# Writing terminal member com.amazonaws.s3#ServerSideEncryption of type enum
# Processing member SSECustomerAlgorithm
# Reached terminal member SSECustomerAlgorithm
# Writing terminal member com.amazonaws.s3#SSECustomerAlgorithm of type string
# Processing member SSEKMSKeyId
# Reached terminal member SSEKMSKeyId
# Writing terminal member com.amazonaws.s3#SSEKMSKeyId of type string
# Processing member SSECustomerKeyMD5
# Reached terminal member SSECustomerKeyMD5
# Writing terminal member com.amazonaws.s3#SSECustomerKeyMD5 of type string
# Processing member StorageClass
# Reached terminal member StorageClass
# Writing terminal member com.amazonaws.s3#StorageClass of type enum
# Processing member TagCount
# Reached terminal member TagCount
# Writing terminal member com.amazonaws.s3#TagCount of type integer
# Processing member VersionId
# Reached terminal member VersionId
# Writing terminal member com.amazonaws.s3#ObjectVersionId of type string
# Processing member BucketKeyEnabled
# Reached terminal member BucketKeyEnabled
# Writing terminal member com.amazonaws.s3#BucketKeyEnabled of type boolean
